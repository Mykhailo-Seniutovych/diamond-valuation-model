# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/diamonds_train.csv')
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 48935   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 48936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 48937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 48938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 48939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [48940 rows x 10 columns]

# %%
data.shape
# Out:
# (48940, 10)

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  48940.000000  48940.000000  48940.000000  48940.000000  48940.000000
# mean       0.798228     61.749144     57.458345   3936.532489      5.731582
# std        0.474353      1.434620      2.239743   3997.909823      1.123013
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    948.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5330.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  48940.000000  48940.000000
# mean       5.735036      3.538968
# std        1.146151      0.707187
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
data.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
ax = data.hist(bins=60, figsize=(20,10))

# %%
plt.subplot(131), data['cut'].value_counts().reindex(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair', 'Poor']).plot(kind='bar', figsize=(15,5))
plt.subplot(132), data['color'].value_counts().reindex(['D','E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Z']).plot(kind='bar', figsize=(15,5))
plt.subplot(133), data['clarity'].value_counts().reindex(['FL', 'IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1', 'I2']).plot(kind='bar', figsize=(15,5))
plt.show()

# %%
ax = data["carat"].hist(bins=50, figsize=(20, 10))
ax.set_xticks(np.arange(0.0, 6.0, 0.1))
plt.show()
outliers = data[data["carat"] > 3.0]
count = outliers.shape[0]
print("outliers_count", count)
# Out:
# outliers_count 26

# %%
ax = data["depth"].hist(bins=50, figsize=(20, 10))
ax.set_xticks(np.arange(0, 100, 2))
plt.show()

outliers = data[np.logical_or(data["depth"] < 56, data["depth"] > 66)]
count = outliers.shape[0]
print("outliers_count", count)
# Out:
# outliers_count 391

# %%
ax = data['table'].hist(bins=50, figsize=(20,10))
ax.set_xticks(np.arange(0, 100, 2))
plt.show()

outliers = data[np.logical_or(data["table"] < 50, data["table"] > 65)]
count = outliers.shape[0]
print("outliers_count", count)
# Out:
# outliers_count 162

# %%
ax = data['price'].hist(bins=100, figsize=(20,10))
ax.set_xticks(np.arange(0, 20001, 1000))
plt.show()

outliers = data[np.logical_or(data["depth"] < 56, data["depth"] > 66)]
count = outliers.shape[0]
print("outliers_count", count)
# Out:
# outliers_count 391

# %%
sns.pairplot(data,x_vars=['carat','cut','color','clarity'], y_vars='price', height=4)
sns.pairplot(data,x_vars=['depth','table','price'], y_vars='price', height=4)
